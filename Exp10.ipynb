# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentiaHarshini4/DWDM/blob/main/Exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.datasets import load_iris

# %%
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)
data['target'] = iris.target

# %%
x = data[['sepal length (cm)', 'sepal width (cm)']]

# %%
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan.fit(x)
labels = dbscan.labels_

# %%
plt.scatter(x['sepal length (cm)'], x['sepal width (cm)'], c=labels)
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.title("DBSCAN Clustering on Iris Dataset")
plt.show()
